# %%
import pandas as pd

df = pd.read_csv("C:/Users/saipr/OneDrive/Documents/Deep Learning/FL-IDS Project/client_metrics_rounds.csv")
df["Round"] = [(i // 3) + 1 for i in range(len(df))]  # Assuming 3 clients per round
df.to_csv("client_metrics_rounds.csv", index=False)
